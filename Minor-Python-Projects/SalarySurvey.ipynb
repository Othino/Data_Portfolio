# %% [markdown]
# <a href="https://colab.research.google.com/github/CynieC/python/blob/main/SalarySurvey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import seaborn as sns
# %matplotlib inline
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#load csv
salary_survey = pd.read_csv("/content/drive/MyDrive/IT Salary Survey EU  2020.csv")

# %%
#top 5 items
salary_survey.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
#bottom 5 items
salary_survey.tail()
# Out:
#                 Timestamp   Age Gender         City  \
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 1248                       Backend Developer                         9
# 1249  Researcher/ Consumer Insights Analyst                         10
# 1250                   IT Operations Manager                        15
# 1251                      Frontend Developer                         7
# 1252                                  DevOps                         2
#
#      Years of experience in Germany Seniority level  \
# 1248                              5          Senior
# 1249                            1.5          Senior
# 1250                              2            Lead
# ...

# %%
#describe the dataframe
salary_survey.describe().transpose()
# Out:
#                                                      count          mean  \
# Age                                                 1226.0  3.250979e+01
# Yearly brutto salary (without bonus and stocks)...  1253.0  8.027904e+07
# Annual brutto salary (without bonus and stocks)...   885.0  6.322459e+05
# Have you been forced to have a shorter working ...   373.0  1.296783e+01
#
#                                                              std      min  \
# Age                                                 5.663804e+00     20.0
# Yearly brutto salary (without bonus and stocks)...  2.825061e+09  10001.0
# Annual brutto salary (without bonus and stocks)...  1.680508e+07  11000.0
# Have you been forced to have a shorter working ...  1.527517e+01      0.0
#
#                                                         25%      50%      75%  \
# Age                                                    29.0     32.0     35.0
# ...

# %%
#get an overview of dataset columns
salary_survey.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status', 'Сontract duration',
#        'Main language at work', 'Company size', 'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
# ...

# %%
#delete unnecessary columns
salary_survey.drop(['Years of experience in Germany', 'Other technologies/programming languages you use often','Сontract duration','Employment status','Have you lost your job due to the coronavirus outbreak?'], axis=1, inplace =True)

# %%
#rename columns and remove any spaces between the column names
salary_survey.columns = ["Year", "Age", "Gender","City","Position","Total_experience","Seniority level","Tech_language",
                       "Yearly salary","Annual bonus and stocks", "Salary previous year","Bonus and stocks previous year","Vacation days",
                       "work_language","Company_size","Company_type","Kurzarbeit","Monetary Support"]

salary_survey.columns = salary_survey.columns.str.replace(' ', '_')

# %%
#Check rows and columns
salary_survey.shape
# Out:
# (1253, 18)

# %%
#check dataset info
salary_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            1253 non-null   object
#  1   Age                             1226 non-null   float64
#  2   Gender                          1243 non-null   object
#  3   City                            1253 non-null   object
#  4   Position                        1247 non-null   object
#  5   Total_experience                1237 non-null   object
#  6   Seniority_level                 1241 non-null   object
#  7   Tech_language                   1126 non-null   object
#  8   Yearly_salary                   1253 non-null   float64
#  9   Annual_bonus_and_stocks         829 non-null    object
#  10  Salary_previous_year            885 non-null    float64
#  11  Bonus_and_stocks_previous_year  614 non-null    object
# ...

# %%
#check data types
salary_survey.dtypes
# Out:
# Year                               object
# Age                               float64
# Gender                             object
# City                               object
# Position                           object
# Total_experience                   object
# Seniority_level                    object
# Tech_language                      object
# Yearly_salary                     float64
# Annual_bonus_and_stocks            object
# Salary_previous_year              float64
# Bonus_and_stocks_previous_year     object
# Vacation_days                      object
# work_language                      object
# Company_size                       object
# Company_type                       object
# Kurzarbeit                        float64
# Monetary_Support                   object
# dtype: object

# %%
#Checking for missing values
salary_survey.isnull().sum()
# Out:
# Year                                0
# Age                                27
# Gender                             10
# City                                0
# Position                            6
# Total_experience                   16
# Seniority_level                    12
# Tech_language                     127
# Yearly_salary                       0
# Annual_bonus_and_stocks           424
# Salary_previous_year              368
# Bonus_and_stocks_previous_year    639
# Vacation_days                      68
# work_language                      16
# Company_size                       18
# Company_type                       25
# Kurzarbeit                        880
# Monetary_Support                  791
# dtype: int64

# %%
#Replace Nan with previous values
salary_survey = salary_survey.fillna(method='ffill')
salary_survey
# Out:
#                      Year   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                     Position Total_experience Seniority_level  \
# 0                          Software Engineer                5          Senior
# 1                          Backend Developer                7          Senior
# 2                          Software Engineer               12            Lead
# ...

# %%
#check most frequent values in columns with numeric values
salary_survey.mode(numeric_only=True)
# Out:
#     Age  Yearly_salary  Salary_previous_year  Kurzarbeit
# 0  30.0        60000.0               60000.0         0.0

# %%
#Remove duplicates
salary_survey = salary_survey.drop_duplicates(keep=False)

# %%
#convert the date column to datetime format
salary_survey['Year'] = pd.to_datetime(salary_survey['Year'])

# %%
# extract the year from the date column
salary_survey['Year'] = salary_survey['Year'].dt.year
salary_survey.head()
# Out:
#    Year   Age Gender    City            Position Total_experience  \
# 0  2020  26.0   Male  Munich   Software Engineer                5
# 1  2020  26.0   Male  Berlin   Backend Developer                7
# 2  2020  29.0   Male  Berlin   Software Engineer               12
# 3  2020  28.0   Male  Berlin  Frontend Developer                4
# 4  2020  37.0   Male  Berlin   Backend Developer               17
#
#   Seniority_level            Tech_language  Yearly_salary  \
# 0          Senior               TypeScript        80000.0
# 1          Senior                     Ruby        80000.0
# 2            Lead  Javascript / Typescript       120000.0
# 3          Junior               Javascript        54000.0
# 4          Senior                  C# .NET        62000.0
#
#   Annual_bonus_and_stocks  Salary_previous_year  \
# 0                    5000               75000.0
# 1                    5000               82000.0
# 2                  120000              100000.0
# ...

# %%
#check value count in seniority_level column
salary_survey['Seniority_level'].value_counts()
# Out:
# Senior                                       571
# Middle                                       369
# Lead                                         169
# Junior                                        79
# Head                                          44
# Principal                                      3
# student                                        1
# Intern                                         1
# Entry level                                    1
# Working Student                                1
# C-Level                                        1
# no idea, there are no ranges in the firm       1
# Student                                        1
# intern                                         1
# Key                                            1
# C-level executive manager                      1
# Director                                       1
# No level                                       1
# CTO                                            1
# ...

# %%
#Replace values in  seniority_level column
salary_survey['Seniority_level']=salary_survey['Seniority_level'].replace({'Lead':'Senior','Head':'Senior','Principal':'Senior','C-Level':'Senior','C-level executive manager':'Senior','CTO':'Senior','Director':'Senior','Work Center Manager':'Senior','Manager':'Senior','VP':'Senior','Entry level':'Junior','intern':'Junior','Intern':'Junior','Student':'No_experience','Working Student':'Junior','no idea, there are no ranges in the firm':'Junior','Key':'No_experience','No level':'No_experience'})

# %%
#check vlaue count ofgender column
salary_survey['Gender'].value_counts()
# Out:
# Male       1057
# Female      194
# Diverse       2
# Name: Gender, dtype: int64
